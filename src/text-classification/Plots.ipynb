# %%
import matplotlib.pyplot as plt
# TOTAL TASKS ["cola", "sst2", "mrpc", "stsb", "qqp", "mnli", "qnli", "rte", "wnli"]

### BERT_BASE

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["sst2", "mrpc", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_ACCURACY = [0.49, 0.32, 0.63, 0.36, 0.50, 0.53, 0.56]
ax.bar(TASK_NAMES,EVAL_ACCURACY)

plt.title('Evaluation Accuracy -- BERT_BASE')
plt.xlabel('Tasks')
plt.ylabel('Eval_Accuracy')

plt.show()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["cola", "sst2", "mrpc", "stsb", "qqp", "mnli", "qnli", "rte", "wnli"]
eval_runtime = [363, 331, 145, 536, 14963, 3479, 2188, 110, 30]
ax.bar(TASK_NAMES,eval_runtime)

plt.title('Evaluation Runtime -- BERT_BASE')
plt.xlabel('Tasks')
plt.ylabel('seconds')

plt.show()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["sst2", "mrpc", "stsb", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_LOSS = [0.82, 1.11, 5.11, 0.72, 1.11, 0.85, 0.84, 0.80]
ax.bar(TASK_NAMES,EVAL_LOSS)

plt.title('Evaluation Loss -- BERT_BASE')
plt.xlabel('Tasks')
plt.ylabel('loss')

plt.show()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["cola", "sst2", "mrpc", "stsb", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_SAMPLE_PER_SECOND = [2.870, 2.802, 2.807, 2.795, 2.702, 2.825, 2.497, 2.509, 2.332]
ax.bar(TASK_NAMES,EVAL_SAMPLE_PER_SECOND)

plt.title('Samples Per Second -- BERT_BASE')
plt.xlabel('Tasks')
plt.ylabel('Samples Per Second')

plt.show()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["cola", "sst2", "mrpc", "stsb", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_STEPS_PER_SECOND = [0.361, 0.35, 0.351, 0.35, 0.338, 0.353, 0.312, 0.317, 0.296]
ax.bar(TASK_NAMES,EVAL_STEPS_PER_SECOND)

plt.title('Steps Per Second -- BERT_BASE')
plt.xlabel('Tasks')
plt.ylabel('Steps Per Second')

plt.show()

### ALBERT_BASE

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["sst2", "mrpc", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_ACCURACY = [0.49, 0.31, 0.63, 0.33, 0.49, 0.51, 0.56]
ax.bar(TASK_NAMES,EVAL_ACCURACY)

plt.title('Evaluation ACCURACY -- ALBERT_BASE')
plt.xlabel('Tasks')
plt.ylabel('Eval_Accuracy')

plt.show()


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["sst2", "mrpc", "stsb", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_LOSS = [0.83, 0.96, 8.75, 0.69, 1.23, 0.79, 0.73, 0.72]
ax.bar(TASK_NAMES,EVAL_LOSS)

plt.title('Evaluation Loss -- ALBERT_BASE')
plt.xlabel('Tasks')
plt.ylabel('loss')

plt.show()

# %%
### BERT LARGE

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["sst2", "mrpc", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_ACCURACY = [0.4931, 0.3162, 0.6146, 0.3172, 0.5188, 0.5307, 0.5634]
ax.bar(TASK_NAMES,EVAL_ACCURACY)

plt.title('Evaluation Loss -- BERT_LARGE_CASED')
plt.xlabel('Tasks')
plt.ylabel('Eval_Accuracy')

plt.show()


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["sst2", "mrpc", "stsb", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_LOSS = [0.7001, 0.8221, 15.138, 0.6849, 1.31, 0.6858, 0.7047, 0.6839]
ax.bar(TASK_NAMES,EVAL_LOSS)

plt.title('Evaluation Loss -- BERT_LARGE_CASED')
plt.xlabel('Tasks')
plt.ylabel('Eval loss')

plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["cola", "sst2", "mrpc", "stsb", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_LOSS = [0.67, 0.51, 0.68, 7.59, 0.71, 1.10, 0.70, 0.70, 0.70]
ax.bar(TASK_NAMES,EVAL_LOSS)

plt.title('Evaluation Loss -- ROBERTA_BASE')
plt.xlabel('Tasks')
plt.ylabel('loss')

plt.show()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["sst2", "mrpc", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_ACCURACY = [0.51, 0.68, 0.37, 0.32, 0.51, 0.47, 0.44]
ax.bar(TASK_NAMES,EVAL_ACCURACY)

plt.title('Evaluation Accuracy -- ROBERTA_BASE')
plt.xlabel('Tasks')
plt.ylabel('Eval_Accuracy')

plt.show()

# %%
### XLNET ####

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["sst2", "mrpc", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_ACCURACY = [0.49, 0.36, 0.63, 0.34, 0.50, 0.51, 0.493]
ax.bar(TASK_NAMES,EVAL_ACCURACY)


plt.title('Evaluation Accuracy -- XLNET-CASED')
plt.xlabel('Tasks')
plt.ylabel('Eval_Accuracy')

plt.show()


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["cola","sst2", "mrpc", "stsb", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_LOSS = [0.77, 0.73, 0.75, 7.97, 0.66, 1.16, 0.74, 0.72, 0.7078]
ax.bar(TASK_NAMES,EVAL_LOSS)

plt.title('Evaluation Loss -- XLNET-CASED')
plt.xlabel('Tasks')
plt.ylabel('loss')

plt.show()







fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["sst2", "mrpc", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_ACCURACY = [0.49, 0.51, 0.40, 0.34, 0.53, 0.47, 0.42]
ax.bar(TASK_NAMES,EVAL_ACCURACY)


plt.title('Evaluation Accuracy -- XLNET-LARGE-CASED')
plt.xlabel('Tasks')
plt.ylabel('Eval_Accuracy')

plt.show()


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["cola","sst2", "mrpc", "stsb", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_LOSS = [0.68,  0.71, 0.70, 9.78, 0.73, 1.11, 00.70, 0.73,  0.76]
ax.bar(TASK_NAMES,EVAL_LOSS)

plt.title('Evaluation Loss -- XLNET-LARGE-CASED')
plt.xlabel('Tasks')
plt.ylabel('loss')

plt.show()

# %%
### NUMBER OF PARAMETERS ACROSS MODELS

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
MODEL_NAMES = ["Albert", "Bert-Base", "Bert-Large", "XLNet-Base", "XLNet-Large", "RoBERTa-Base"]
NUMBER_OF_PARAMS = [110000000, 109000000, 335000000, 110000000, 340000000, 125000000]
ax.bar(MODEL_NAMES, NUMBER_OF_PARAMS)

plt.title('Number of Parameters in each model')
plt.xlabel('Models')
plt.ylabel('Nunber of Parameters')

plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["sst2", "mrpc", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_ACCURACY_BERT_BASE = [0.49, 0.32, 0.63, 0.36, 0.50, 0.53, 0.56]
EVAL_ACCURACY_ALBERT_BASE = [0.49, 0.31, 0.63, 0.33, 0.49, 0.51, 0.56]
EVAL_ACCURACY_BERT_LARGE_CASED = [0.4931, 0.3162, 0.6146, 0.3172, 0.5188, 0.5307, 0.5634]
EVAL_ACCURACY_ROBERTA_BASE = [0.51, 0.68, 0.37, 0.32, 0.51, 0.47, 0.44]
EVAL_ACCURACY_XL_NET = [0.49, 0.36, 0.63, 0.34, 0.50, 0.51, 0.493]
EVAL_ACCURACY_XL_NET_LARGE_CASED = [0.49, 0.51, 0.40, 0.34, 0.53, 0.47, 0.42]

ax.plot(TASK_NAMES,EVAL_ACCURACY_BERT_BASE)
ax.plot(TASK_NAMES,EVAL_ACCURACY_ALBERT_BASE)
ax.plot(TASK_NAMES,EVAL_ACCURACY_BERT_LARGE_CASED)
ax.plot(TASK_NAMES,EVAL_ACCURACY_ROBERTA_BASE)
ax.plot(TASK_NAMES,EVAL_ACCURACY_XL_NET)
ax.plot(TASK_NAMES,EVAL_ACCURACY_XL_NET_LARGE_CASED)

plt.title('Evaluation Accuracy Comparison')
plt.xlabel('Tasks')
plt.ylabel('Eval_Accuracy')
plt.legend(['EVAL_ACCURACY_BERT_BASE','EVAL_ACCURACY_ALBERT_BASE','EVAL_ACCURACY_BERT_LARGE_CASED','EVAL_ACCURACY_ROBERTA_BASE','EVAL_ACCURACY_XL_NET','EVAL_ACCURACY_XL_NET_LARGE_CASED'])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
TASK_NAMES = ["sst2", "mrpc", "stsb", "qqp", "mnli", "qnli", "rte", "wnli"]
EVAL_LOSS_BERT_BASE = [0.82, 1.11, 5.11, 0.72, 1.11, 0.85, 0.84, 0.80]
EVAL_LOSS_ALBERT_BASE = [0.83, 0.96, 8.75, 0.69, 1.23, 0.79, 0.73, 0.72]
EVAL_LOSS_BERT_LARGE_CASED = [0.7001, 0.8221, 15.138, 0.6849, 1.31, 0.6858, 0.7047, 0.6839]
EVAL_LOSS_ROBERTA_BASE =  [0.51, 0.68, 7.59, 0.71, 1.10, 0.70, 0.70, 0.70]
EVAL_LOSS_XL_NET = [0.73, 0.75, 7.97, 0.66, 1.16, 0.74, 0.72, 0.7078]
EVAL_LOSS_XL_NET_LARGE_CASED = [0.71, 0.70, 9.78, 0.73, 1.11, 00.70, 0.73,  0.76]

ax.plot(TASK_NAMES,EVAL_LOSS_BERT_BASE)
ax.plot(TASK_NAMES,EVAL_LOSS_ALBERT_BASE)
ax.plot(TASK_NAMES,EVAL_LOSS_BERT_LARGE_CASED)
ax.plot(TASK_NAMES,EVAL_LOSS_ROBERTA_BASE)
ax.plot(TASK_NAMES,EVAL_LOSS_XL_NET)
ax.plot(TASK_NAMES,EVAL_LOSS_XL_NET_LARGE_CASED)

plt.title('Evaluation Loss Comparison')
plt.xlabel('Tasks')
plt.ylabel('Eval_Loss')
plt.legend(['EVAL_LOSS_BERT_BASE','EVAL_LOSS_ALBERT_BASE','EVAL_LOSS_BERT_LARGE_CASED','EVAL_LOSS_ROBERTA_BASE','EVAL_LOSS_XL_NET','EVAL_LOSS_XL_NET_LARGE_CASED'])
plt.show()
